# %%
import pandas as pd

# %%
df = pd.read_csv('simple_pull.csv')

# %%
df
# Out:
#           PhotoID                                              Title  \
# 0     52748254383  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 1     52748254428  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 2     52748254463  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 3     52748172745  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 4     52748007544  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# ...           ...                                                ...
# 9323  53185117536  TAuch_Infrastructure-Offshore_DrillRig_Constru...
# 9324  53185319835  TAuch_Transportation-GalvestonCounty-TX_August...
# 9325  53185487873  TAuch_Infrastructure-Offshore_DrillRig_Constru...
# 9326  53185487878  TAuch_Infrastructure-Offshore_DrillRig_Constru...
# 9327  53185487888  TAuch_Infrastructure-Offshore_DrillRig_Constru...
#
#                Date_taken                                        Description  \
# ...

# %%
grouped_df = df.groupby('PhotoID')['AlbumTitle'].agg(list).reset_index()

# %%
grouped_df
# Out:
#           PhotoID                                         AlbumTitle
# 0     49727911618                                 [Frac Sand Mining]
# 1     49727914298    [Frac Sand Mining, Illinois, Impoundment Ponds]
# 2     49727914638  [Frac Sand Mining, Frac Sand Transportation, I...
# 3     49727915018    [Frac Sand Mining, Illinois, Impoundment Ponds]
# 4     49727915083    [Frac Sand Mining, Illinois, Impoundment Ponds]
# ...           ...                                                ...
# 2682  53706158340  [Communities, Culture & Livelihoods, Environme...
# 2683  53706158375  [Communities, Culture & Livelihoods, Environme...
# 2684  53706158545  [Communities, Culture & Livelihoods, Environme...
# 2685  53706158630  [Communities, Culture & Livelihoods, Environme...
# 2686  53706158655  [Communities, Culture & Livelihoods, Environme...
#
# [2687 rows x 2 columns]
